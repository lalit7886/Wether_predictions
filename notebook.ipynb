# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('/Users/lalitramanmishra/Wether_predictions/GlobalWeatherRepository.csv')

# %%
df.shape
# Out:
# (148710, 41)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 148710 entries, 0 to 148709
# Data columns (total 41 columns):
#  #   Column                        Non-Null Count   Dtype
# ---  ------                        --------------   -----
#  0   country                       148710 non-null  object
#  1   location_name                 148710 non-null  object
#  2   latitude                      148710 non-null  float64
#  3   longitude                     148710 non-null  float64
#  4   timezone                      148710 non-null  object
#  5   last_updated_epoch            148710 non-null  int64
#  6   last_updated                  148710 non-null  object
#  7   temperature_celsius           148710 non-null  float64
#  8   temperature_fahrenheit        148710 non-null  float64
#  9   condition_text                148710 non-null  object
#  10  wind_mph                      148710 non-null  float64
#  11  wind_kph                      148710 non-null  float64
#  12  wind_degree                   148710 non-null  int64
#  13  wind_direction                148710 non-null  object
#  14  pressure_mb                   148710 non-null  float64
#  15  pressure_in                   148710 non-null  float64
#  16  precip_mm                     148710 non-null  float64
#  17  precip_in                     148710 non-null  float64
#  18  humidity                      148710 non-null  int64
#  19  cloud                         148710 non-null  int64
#  20  feels_like_celsius            148710 non-null  float64
#  21  feels_like_fahrenheit         148710 non-null  float64
#  22  visibility_km                 148710 non-null  float64
#  23  visibility_miles              148710 non-null  float64
#  24  uv_index                      148710 non-null  float64
#  25  gust_mph                      148710 non-null  float64
#  26  gust_kph                      148710 non-null  float64
#  27  air_quality_Carbon_Monoxide   148710 non-null  float64
#  28  air_quality_Ozone             148710 non-null  float64
#  29  air_quality_Nitrogen_dioxide  148710 non-null  float64
#  30  air_quality_Sulphur_dioxide   148710 non-null  float64
#  31  air_quality_PM2.5             148710 non-null  float64
#  32  air_quality_PM10              148710 non-null  float64
#  33  air_quality_us-epa-index      148710 non-null  int64
#  34  air_quality_gb-defra-index    148710 non-null  int64
#  35  sunrise                       148710 non-null  object
#  36  sunset                        148710 non-null  object
#  37  moonrise                      148710 non-null  object
#  38  moonset                       148710 non-null  object
#  39  moon_phase                    148710 non-null  object
#  40  moon_illumination             148710 non-null  int64
# dtypes: float64(23), int64(7), object(11)
# memory usage: 46.5+ MB

# %%
df.describe()
# Out:
#             latitude      longitude  last_updated_epoch  temperature_celsius  \
# count  148710.000000  148710.000000        1.487100e+05        148710.000000
# mean       19.230689      21.905139        1.748946e+09            21.295698
# std        24.405598      65.780334        1.910594e+07             9.548069
# min       -41.300000    -175.200000        1.715849e+09           -29.800000
# 25%         4.050300      -6.836100        1.732437e+09            16.000000
# 50%        17.250000      23.236100        1.748941e+09            23.600000
# 75%        40.400000      49.882200        1.765437e+09            27.900000
# max        65.300000     179.220000        1.782022e+09            79.300000
#
#        temperature_fahrenheit       wind_mph       wind_kph    wind_degree  \
# count           148710.000000  148710.000000  148710.000000  148710.000000
# mean                70.334047       7.954148      12.804733     169.266875
# std                 17.186389       7.048841      11.340589     103.520400
# min                -21.600000       2.200000       3.600000       1.000000
# 25%                 60.800000       3.800000       6.100000      80.000000
# 50%                 74.500000       6.700000      10.800000     162.000000
# 75%                 82.200000      11.000000      17.600000     256.000000
# max                174.700000    1841.200000    2963.200000     360.000000
#
#          pressure_mb    pressure_in  ...       gust_kph  \
# count  148710.000000  148710.000000  ...  148710.000000
# mean     1014.059471      29.944589  ...      18.120720
# std        10.045609       0.296595  ...      13.583539
# min       947.000000      27.960000  ...       3.600000
# 25%      1010.000000      29.830000  ...      10.100000
# 50%      1014.000000      29.930000  ...      15.200000
# 75%      1018.000000      30.060000  ...      24.000000
# max      3006.000000      88.770000  ...    2970.400000
#
#        air_quality_Carbon_Monoxide  air_quality_Ozone  \
# count                148710.000000      148710.000000
# mean                    441.300593          57.618802
# std                     732.304436          30.593026
# min                   -9999.000000           0.000000
# 25%                     190.300000          38.000000
# 50%                     281.850000          54.400000
# 75%                     444.000000          73.000000
# max                   38879.398000         480.700000
#
#        air_quality_Nitrogen_dioxide  air_quality_Sulphur_dioxide  \
# count                 148710.000000                148710.000000
# mean                      14.591029                     9.980983
# std                       23.049638                    34.230777
# min                        0.000000                 -9999.000000
# 25%                        1.750000                     1.110000
# 50%                        5.650000                     2.405000
# 75%                       16.650000                     7.955000
# max                      427.700000                   521.330000
#
#        air_quality_PM2.5  air_quality_PM10  air_quality_us-epa-index  \
# count      148710.000000     148710.000000             148710.000000
# mean           23.560149         47.272023                  1.676323
# std            35.829215        145.736112                  0.928675
# min             0.168000      -1848.150000                  1.000000
# 25%             6.950000          9.750000                  1.000000
# 50%            13.690000         19.350000                  1.000000
# 75%            27.010000         40.450000                  2.000000
# max          1614.100000       6037.290000                  6.000000
#
#        air_quality_gb-defra-index  moon_illumination
# count               148710.000000      148710.000000
# mean                     2.552545          49.693652
# std                      2.407625          35.080560
# min                      1.000000           0.000000
# 25%                      1.000000          15.000000
# 50%                      2.000000          49.000000
# 75%                      3.000000          85.000000
# max                     10.000000         100.000000
#
# [8 rows x 30 columns]

# %%
kabul=df[df["location_name"]=="Kabul"]

# %%
kabul.shape
# Out:
# (765, 41)

# %%
import seaborn as sns

# %%
corr_matrix=df.corr(numeric_only=True)
plt.figure(figsize=(20, 20))
sns.heatmap(corr_matrix,
            annot=True,
            cmap='coolwarm',
            fmt='.2f')

plt.show()
